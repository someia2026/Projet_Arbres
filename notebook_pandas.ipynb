# %%
import pandas as pd
df = pd.read_csv("data/data_trees.csv", sep=",", header = 0, index_col=False,names=None)

# %%
df.head(2) #affiche les 2 premières lignes
# Out:
#    elem_point_id      code      nom genre  genre_desc categorie  \
# 0          34835  ESP36318  AR36318   VEG  VEGETATION     ESP01
# 1          34836  ESP36319  AR36319   VEG  VEGETATION     ESP01
#
#   categorie_desc sous_categorie sous_categorie_desc code_parent  ...  \
# 0          Arbre         ESP151     Arbre de voirie      ESP237  ...
# 1          Arbre         ESP151     Arbre de voirie      ESP237  ...
#
#   diametrearbre  causeabattage              collectivite stationmetro  \
# 0           NaN            NaN  Grenoble Alpes Métropole          NaN
# 1           NaN            NaN  Grenoble Alpes Métropole          NaN
#
#   hauteurarbre portarbre              structure  forme typenature  \
# 0          NaN       NaN  Métropole de Grenoble    NaN        NaN
# 1          NaN       NaN  Métropole de Grenoble    NaN        NaN
#
#                            geo_point_2d
# 0  45.167098421885385,5.740131798404362
# 1   45.16710682038838,5.740199792549315
#
# ...

# %%
print(df.iloc[:, :2]) #affiche les  premières colonnes
# Out:
#        elem_point_id      code
# 0              34835  ESP36318
# 1              34836  ESP36319
# 2              34837  ESP36320
# 3              34838  ESP36321
# 4              34839  ESP36322
# ...              ...       ...
# 31665          44741  ESP40744
# 31666          44742  ESP40745
# 31667          44841  ESP40796
# 31668          44842  ESP40797
# 31669          44982  ESP40913
#
# [31670 rows x 2 columns]

# %%
#créer une liste avec la colonne année_de_plantation
list_annee = df["anneedeplantation"].tolist()
print(list_annee)
# Out:
# [2015.0, 2015.0, 2015.0, 2015.0, 2015.0, 2015.0, 2015.0, 2015.0, 2015.0, 2015.0, 2015.0, 2015.0, 1975.0, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, 1996.0, 1996.0, nan, nan, 1996.0, 2016.0, 2016.0, 2016.0, 2016.0, 2016.0, 2016.0, 2017.0, 1978.0, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, 2016.0, 2018.0, 2018.0, 2018.0, 2018.0, 2018.0, 2018.0, 2018.0, 2018.0, 2018.0, 2018.0, 2018.0, 2018.0, 2018.0, 2018.0, 2018.0, 2018.0, 2018.0, 2018.0, 2018.0, 2018.0, 2018.0, 2018.0, 2018.0, 2017.0, 2018.0, 2018.0, 2018.0, 2018.0, 2018.0, 2018.0, 2018.0, nan, nan, 2017.0, 2017.0, 2017.0, 2017.0, 2017.0, 2017.0, 2018.0, 2018.0, nan, nan, nan, nan, 1978.0, 2018.0, 2018.0, 2018.0, 2018.0, 2018.0, 2018.0, 2018.0, 2017.0, 2017.0, 2017.0, 2017.0, 2017.0, 2017.0, 2017.0, 2017.0, 2017.0, 2018.0, 2018.0, 2018.0, 2018.0, 2018.0, 2018.0, 2018.0, 2018.0, 2018.
# ...

# %%
#afficher les 50 premières lignes
df.head(50)
# Out:
#     elem_point_id      code      nom genre  genre_desc categorie  \
# 0           34835  ESP36318  AR36318   VEG  VEGETATION     ESP01
# 1           34836  ESP36319  AR36319   VEG  VEGETATION     ESP01
# 2           34837  ESP36320  AR36320   VEG  VEGETATION     ESP01
# 3           34838  ESP36321  AR36321   VEG  VEGETATION     ESP01
# 4           34839  ESP36322  AR36322   VEG  VEGETATION     ESP01
# 5           34840  ESP36323  AR36323   VEG  VEGETATION     ESP01
# 6           34841  ESP36324  AR36324   VEG  VEGETATION     ESP01
# 7           34842  ESP36325  AR36325   VEG  VEGETATION     ESP01
# 8           34843  ESP36326  AR36326   VEG  VEGETATION     ESP01
# 9           34844  ESP36327  AR36327   VEG  VEGETATION     ESP01
# 10          34845  ESP36328  AR36328   VEG  VEGETATION     ESP01
# 11          34846  ESP36329  AR36329   VEG  VEGETATION     ESP01
# 12          16799  ESP19333  AR19333   VEG  VEGETATION     ESP01
# ...

# %%
#afficher les 50 dernières lignes
df.tail(50)
# Out:
#        elem_point_id      code      nom genre  genre_desc categorie  \
# 31620          45251  ESP41044  AR41044   VEG  VEGETATION     ESP01
# 31621          45252  ESP41045  AR41045   VEG  VEGETATION     ESP01
# 31622          45253  ESP41046  AR41046   VEG  VEGETATION     ESP01
# 31623          45254  ESP41047  AR41047   VEG  VEGETATION     ESP01
# 31624          45255  ESP41048  AR41048   VEG  VEGETATION     ESP01
# 31625          45256  ESP41049  AR41049   VEG  VEGETATION     ESP01
# 31626          45257  ESP41050  AR41050   VEG  VEGETATION     ESP01
# 31627          45258  ESP41051  AR41051   VEG  VEGETATION     ESP01
# 31628          45259  ESP41052  AR41052   VEG  VEGETATION     ESP01
# 31629          45260  ESP41053  AR41053   VEG  VEGETATION     ESP01
# 31630          45261  ESP41054  AR41054   VEG  VEGETATION     ESP01
# 31631          34954  ESP36405  AR36405   VEG  VEGETATION     ESP01
# 31632          34955  ESP36406  AR36406   VEG  VEGETATION     ESP01
# ...

# %%
#Arbres sont recensés dans ce jeu de données

row_count =len(df)
print("le nombres d'arbres est",row_count)
# Out:
# le nombres d'arbres est 31670

# %%
#Le nombres d'arbres auxquels il manque la date de plantation
nb_blank_year = df['anneedeplantation'].isna().sum()
print("Le nombre d'arbres dont la date de plantation est manquante est", nb_blank_year)
# Out:
# Le nombre d'arbres dont la date de plantation est manquante est 2144

# %%
#Combien d'arbres ont été plantés l'année de ma naissance (2015) => réponse attendue selon excel 1000.

list_annee = df["anneedeplantation"].tolist()
counts = (df['anneedeplantation'] =="2015").sum()
print("le nombre d'arbres plantés en 2015 est de ", counts, "arbres")
# Out:
# le nombre d'arbres plantés en 2015 est de  0 arbres

# %%
# La plus récente année de plantation
"L'année de plantation la plus récente est", df['anneedeplantation'].max()
# Out:
# ("L'année de plantation la plus récente est", 2024.0)

# %%
# La plus ancienne année de plantation
"L'année de plantation la plus ancienne est", df['anneedeplantation'].min()
# Out:
# ("L'année de plantation la plus ancienne est", 1900.0)

# %%
#Quelle structure a planté le plus d'arbres à Grenoble

# %%
# Informations manquantes concernant le genre botanique
# list_annee = df["anneedeplantation"].tolist()
# list_annee_structure = df["structure"].tolist()
nb_blank_year = df['structure'].isna().sum()
print("Le nombre d'ainformation manquante  de genre botanique est", nb_blank_year)
# Out:
# Le nombre d'ainformation manquante  de genre botanique est 826

# %%
# Rafraîchissement du dataset
import pandas as pd
df = pd.read_csv("data/data_trees.csv", sep=",", header = 0, index_col=False,names=None)
df.head(2)
# Out:
#    elem_point_id      code      nom genre  genre_desc categorie  \
# 0          34835  ESP36318  AR36318   VEG  VEGETATION     ESP01
# 1          34836  ESP36319  AR36319   VEG  VEGETATION     ESP01
#
#   categorie_desc sous_categorie sous_categorie_desc code_parent  ...  \
# 0          Arbre         ESP151     Arbre de voirie      ESP237  ...
# 1          Arbre         ESP151     Arbre de voirie      ESP237  ...
#
#   diametrearbre  causeabattage              collectivite stationmetro  \
# 0           NaN            NaN  Grenoble Alpes Métropole          NaN
# 1           NaN            NaN  Grenoble Alpes Métropole          NaN
#
#   hauteurarbre portarbre              structure  forme typenature  \
# 0          NaN       NaN  Métropole de Grenoble    NaN        NaN
# 1          NaN       NaN  Métropole de Grenoble    NaN        NaN
#
#                            geo_point_2d
# 0  45.167098421885385,5.740131798404362
# 1   45.16710682038838,5.740199792549315
#
# ...

# %%
import pandas as pd
df = pd.read_csv("data/data_trees.csv", sep=",", header = 0, index_col=False,names=None)
df.sort_values(by= "anneedeplantation", ascending=True, na_position='first')

# trier la data par années de plantation
# Out:
#        elem_point_id      code      nom genre  genre_desc categorie  \
# 13             43307  ESP39945  AR39945   VEG  VEGETATION     ESP01
# 14             43308  ESP39946  AR39946   VEG  VEGETATION     ESP01
# 15             43309  ESP39947  AR39947   VEG  VEGETATION     ESP01
# 16             43311  ESP39949  AR39949   VEG  VEGETATION     ESP01
# 17             43312  ESP39950  AR39950   VEG  VEGETATION     ESP01
# ...              ...       ...      ...   ...         ...       ...
# 27139          48055  ESP43658  AR43658   VEG  VEGETATION     ESP01
# 27140          48056  ESP43659  AR43659   VEG  VEGETATION     ESP01
# 27157          48073  ESP43676  AR43676   VEG  VEGETATION     ESP01
# 22008          48315  ESP43934  AR43934   VEG  VEGETATION     ESP01
# 22007          48314  ESP43933  AR43933   VEG  VEGETATION     ESP01
#
#       categorie_desc sous_categorie      sous_categorie_desc code_parent  ...  \
# ...

# %%
#soustraire aux années de plantations l’année minimale)
df_count = df_count[(df_count['anneedeplantation'] != 1988) & (df_count['anneedeplantation'] != 2024)]
print(df_count)
# Out:
#     anneedeplantation  elem_point_id
# 62             1900.0             25
# 64             1924.0             11
# 61             1944.0             26
# 25             1950.0            396
# 55             1955.0            111
# ..                ...            ...
# 27             2019.0            354
# 49             2020.0            201
# 66             2021.0              5
# 46             2022.0            210
# 50             2023.0            198
#
# [66 rows x 2 columns]

# %%
#les arbres ont été plantés en moyenne chaque année

average = df_count.mean()
print(average)
# Out:
# anneedeplantation    1988.090909
# elem_point_id         444.045455
# dtype: float64
